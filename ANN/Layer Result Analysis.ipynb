# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Define the CSV file path
csv_file_name = "model_results_summary.csv"
current_directory = os.getcwd()
csv_file_path = os.path.join(current_directory, csv_file_name)

# Load the DataFrame
model_results_df = pd.read_csv(csv_file_path)

# Sort the DataFrame by 'Test RMSE' in ascending order
model_results_df_sorted = model_results_df.sort_values(by='R2 Score', ascending=True)

# Set the figure size
plt.figure(figsize=(14, 8))

# Set the x-axis positions
x = range(len(model_results_df_sorted))

# Create a bar plot for Test RMSE
ax1 = plt.subplot()
bar_width = 0.6
bars = ax1.bar(
    x,
    model_results_df_sorted['Test RMSE'],
    width=bar_width,
    color='skyblue',
    label='Test RMSE'
)

# Set labels and title for ax1
ax1.set_xlabel('Architecture', fontsize=12)
ax1.set_ylabel('Test RMSE', fontsize=12, color='blue')
ax1.tick_params(axis='y', labelcolor='blue')

# Adjust x-ticks
ax1.set_xticks(x)
ax1.set_xticklabels(model_results_df_sorted['Architecture'], rotation=45, ha='right')

# Create a twin axis for R² Score
ax2 = ax1.twinx()

# Plot R² Score on the twin axis
ax2.plot(
    x,
    model_results_df_sorted['R2 Score'],
    color='red',
    marker='o',
    linestyle='-',
    linewidth=2,
    label='R² Score'
)

# Set labels for ax2
ax2.set_ylabel('R² Score', fontsize=12, color='red')
ax2.tick_params(axis='y', labelcolor='red')

# Add title
plt.title('Test RMSE and R² Score for Different Neural Network Architectures', fontsize=14)

# Add legends
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines + lines2, labels + labels2, loc='upper right')

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()
